# %%
from langchain_community.document_loaders import CSVLoader
from pathlib import Path
from pprint import pp
# Out:
# C:\Users\koush\AppData\Local\Temp\ipykernel_12956\4202881644.py:1: DeprecationWarning: `langchain-community` is being sunset and is no longer actively maintained. See https://github.com/langchain-ai/langchain-community/issues/674 for details and migration guidance toward standalone integration packages.
#   from langchain_community.document_loaders import CSVLoader

# %%
file_path = Path("./knowledge-source/organizations.csv")
file_path.exists()
# Out:
# True

# %%
csv_loader = CSVLoader(file_path)
documents = csv_loader.load()
len(documents)
# Out:
# 1000

# %%
pp(documents[1].page_content)
# Out:
# ('Index: 2\n'
#  'Organization Id: AAC4f9aBF86EAeF\n'
#  'Name: Orr-Armstrong\n'
#  'Website: https://www.chapman.net/\n'
#  'Country: Algeria\n'
#  'Description: Ergonomic radical budgetary management\n'
#  'Founded: 1970\n'
#  'Industry: Import / Export\n'
#  'Number of employees: 7994')

# %%
pp(documents[1].metadata)
# Out:
# {'source': 'knowledge-source\\organizations.csv', 'row': 1}
